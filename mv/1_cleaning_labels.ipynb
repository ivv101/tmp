# %%
import requests

import pandas as pd
import pickle as pkl
import numpy as np

from collections import Counter
import re
import os
import json

from pandarallel import pandarallel
pandarallel.initialize(progress_bar=False)
# Out:
# INFO: Pandarallel will run on 6 workers.
# INFO: Pandarallel will use Memory file system to transfer data between the main process and workers.

# %% [markdown]
# For this challenge we will need the following files:
#
# 1. https://datasets.imdbws.com/title.basics.tsv.gz
# <!-- 2. https://datasets.imdbws.com/title.ratings.tsv.gz -->
# 3. IMDB_movie_details.json from https://www.kaggle.com/rmisra/imdb-spoiler-dataset/data (requires authorization; already downloaded in 'data' folder)
# 4. http://www.cs.cmu.edu/~ark/personas/data/MovieSummaries.tar.gz

# %%
data_dir = 'data' # folder containing original datasets
tmp_dir = 'tmp' # temporal folder containing intermediate results of Jupyter notebooks

if not os.path.exists(tmp_dir):
    os.mkdir(tmp_dir)

# %%
def download_file(url, path):
        
    file_name = f"{path}/{url.split('/')[-1]}"
    
    if os.path.exists(file_name):
        return file_name 
    
    resp = requests.get(url)

    with open(file_name, 'wb') as f: 
        f.write(resp.content)
    
    if file_name[-7:] == '.tar.gz':
        os.system(f'tar -xf {file_name} -C {path}')    
        
    return file_name

# %%
# %%time

urls = 'https://datasets.imdbws.com/title.basics.tsv.gz', 'http://www.cs.cmu.edu/~ark/personas/data/MovieSummaries.tar.gz'

[download_file(url, data_dir) for url in urls]
# Out:
# CPU times: user 24 µs, sys: 14 µs, total: 38 µs
# Wall time: 39.6 µs
# ['data/title.basics.tsv.gz', 'data/MovieSummaries.tar.gz']

# %% [markdown]
# ### Downloading plot summaries

# %%
plot_summaries = pd.read_csv(f'{data_dir}/MovieSummaries/plot_summaries.txt', 
                             sep='\t', 
                             names=['wiki_id', 'synopsis'], 
                             index_col='wiki_id')
len(plot_summaries)
# Out:
# 42303

# %% [markdown]
# ### Downloading movies metadata

# %%
col_names = ['wiki_id', 'freebase_id', 'name', 'release date', 
             'revenue', 'runtime', 'languages', 'countries', 'genres']

movie_metadata = pd.read_csv('data/MovieSummaries/movie.metadata.tsv', 
                             sep='\t', 
                             names=col_names,
                             index_col='wiki_id')

# %%
no_metadata_ids = list(set(plot_summaries.index).difference(set(movie_metadata.index)))
len(no_metadata_ids)
# Out:
# 99

# %% [markdown]
# ### Merging plot summaries and metadata

# %%
plot_data = pd.merge(plot_summaries, movie_metadata, 
                     left_index=True, right_index=True)

plot_data['genres'] = plot_data['genres'].apply(lambda x : list(eval(x).values()))

no_genre_ids = plot_data['genres'][plot_data['genres'].apply(len) == 0].index.to_list()

plot_data = plot_data.drop(no_genre_ids)

len(no_genre_ids)
# Out:
# 411

# %%
_ = ~plot_data.duplicated(subset=['synopsis'])

plot_data = plot_data[_]
plot_data
# Out:
#                                                    synopsis freebase_id  \
# wiki_id
# 23890098  Shlykov, a hard-working taxi driver and Lyosha...  /m/076w2lb
# 31186339  The nation of Panem consists of a wealthy Capi...  /m/0gkz15s
# 20663735  Poovalli Induchoodan  is sentenced for six yea...  /m/051zjwb
# 2231378   The Lemon Drop Kid , a New York City swindler,...   /m/06xtz3
# 595909    Seventh-day Adventist Church pastor Michael Ch...   /m/02tqm5
# ...                                                     ...         ...
# 34808485  The story is about Reema , a young Muslim scho...  /m/0j3dcl6
# 1096473   In 1928 Hollywood, director Leo Andreyev  look...   /m/045pct
# 35102018  American Luthier focuses on Randy Parsons’ tra...  /m/0j6777g
# 8628195   Abdur Rehman Khan , a middle-aged dry fruit se...  /m/04f7jfs
# 6040782   1940 - Operation Dynamo has just taken place. ...   /m/0fm00m
#
#                                      name release date      revenue  runtime  \
# wiki_id
# 23890098                       Taxi Blues   1990-09-07          NaN    110.0
# 31186339                 The Hunger Games   2012-03-12  686533290.0    142.0
# 20663735                       Narasimham         2000          NaN    175.0
# 2231378                The Lemon Drop Kid   1951-03-08    2300000.0     91.0
# 595909                  A Cry in the Dark   1988-11-03    6908797.0    121.0
# ...                                   ...          ...          ...      ...
# 34808485              Oomakkuyil Padumbol   2012-02-17          NaN      NaN
# 1096473                  The Last Command         1928          NaN     88.0
# 35102018  Randy Parsons: American Luthier   2011-10-04          NaN      8.0
# 8628195                        Kabuliwala   1961-12-14          NaN    134.0
# 6040782                        Dad's Army   1971-03-12          NaN     95.0
#
#                                                   languages  \
# wiki_id
# 23890098                   {"/m/06b_j": "Russian Language"}
# 31186339                 {"/m/02h40lc": "English Language"}
# 20663735                 {"/m/0999q": "Malayalam Language"}
# 2231378                  {"/m/02h40lc": "English Language"}
# 595909                   {"/m/02h40lc": "English Language"}
# ...                                                     ...
# 34808485                 {"/m/0999q": "Malayalam Language"}
# 1096473   {"/m/06ppq": "Silent film", "/m/02h40lc": "Eng...
# 35102018                 {"/m/02h40lc": "English Language"}
# 8628195                      {"/m/03k50": "Hindi Language"}
# 6040782                  {"/m/02h40lc": "English Language"}
#
#                                                   countries  \
# wiki_id
# 23890098  {"/m/0f8l9c": "France", "/m/05vz3zq": "Soviet ...
# 31186339          {"/m/09c7w0": "United States of America"}
# 20663735                              {"/m/03rk0": "India"}
# 2231378           {"/m/09c7w0": "United States of America"}
# 595909    {"/m/09c7w0": "United States of America", "/m/...
# ...                                                     ...
# 34808485                              {"/m/03rk0": "India"}
# 1096473           {"/m/09c7w0": "United States of America"}
# 35102018          {"/m/09c7w0": "United States of America"}
# 8628195                               {"/m/03rk0": "India"}
# 6040782                      {"/m/07ssc": "United Kingdom"}
#
#                                                      genres
# wiki_id
# 23890098                              [Drama, World cinema]
# 31186339  [Action/Adventure, Science Fiction, Action, Dr...
# 20663735                [Musical, Action, Drama, Bollywood]
# 2231378                          [Screwball comedy, Comedy]
# 595909    [Crime Fiction, Drama, Docudrama, World cinema...
# ...                                                     ...
# 34808485                                       [Children's]
# 1096473   [Silent film, Indie, Black-and-white, Period p...
# 35102018  [Short Film, Music, Biographical film, Documen...
# 8628195                                             [Drama]
# 6040782                                            [Comedy]
#
# [41785 rows x 9 columns]

# %%
genres_data = plot_data['genres'].to_list()
genres_data[:10]
# Out:
# [['Drama', 'World cinema'],
#  ['Action/Adventure', 'Science Fiction', 'Action', 'Drama'],
#  ['Musical', 'Action', 'Drama', 'Bollywood'],
#  ['Screwball comedy', 'Comedy'],
#  ['Crime Fiction', 'Drama', 'Docudrama', 'World cinema', 'Courtroom Drama'],
#  ['Thriller', 'Action/Adventure', 'Action', 'Drama'],
#  ['Thriller', 'Drama', 'Horror'],
#  ['Drama', 'Teen'],
#  ['Romantic comedy',
#   'Media Satire',
#   'Americana',
#   'Comedy-drama',
#   'Black-and-white',
#   'Drama',
#   'Comedy',
#   'Romance Film'],
#  ['Short Film', 'Family Film', 'Animation']]

# %% [markdown]
# ### The dataset contains too many genres. Let us look at the genres used in imdb dataset

# %%
# %time title_basics = pd.read_csv('data/title.basics.tsv.gz', sep='\t', low_memory=False)
genres_imdb = title_basics['genres']
genres_imdb
# Out:
# CPU times: user 15.3 s, sys: 1.61 s, total: 16.9 s
# Wall time: 16.9 s
# 0                   Documentary,Short
# 1                     Animation,Short
# 2            Animation,Comedy,Romance
# 3                     Animation,Short
# 4                        Comedy,Short
#                       ...
# 9553993           Action,Drama,Family
# 9553994           Action,Drama,Family
# 9553995           Action,Drama,Family
# 9553996                         Short
# 9553997    Adventure,Animation,Comedy
# Name: genres, Length: 9553998, dtype: object

# %%
genres_imdb = genres_imdb.dropna().to_list()
genres_imdb = [list(set(_.split(','))) for _ in genres_imdb]

# %%
tally = lambda x : sorted(Counter(x).items(), key=lambda _: _[1])[::-1]

# %%
genres_imdb_unique_tally = tally(np.concatenate(genres_imdb))

# %% [markdown]
# ### Also let us look at the genres used in imdb spoiler dataset

# %%
def read_json_file(file):
    '''
    from https://stackoverflow.com/a/68942058/5242222
    '''
    with open(file, "r") as r:
        response = r.read()
        response = response.replace('\n', '')
        response = response.replace('}{', '},{')
        response = "[" + response + "]"
        return json.loads(response)

# %%
fn = f'{data_dir}/IMDB_movie_details.json'
IMDB_movie_details = read_json_file(fn) #json.load(open(imdb_plots_file, 'rt'))

# %%
_ = [_['genre'] for _ in IMDB_movie_details]

IMDB_movie_details_unique_tally = tally(np.concatenate(_))

# %% [markdown]
# ### Let remove the genres not contained in spoiler dataset

# %%
set(np.transpose(genres_imdb_unique_tally)[0]).symmetric_difference(set(np.transpose(IMDB_movie_details_unique_tally)[0]))
# Out:
# {'Adult',
#  'Documentary',
#  'Experimental',
#  'Game-Show',
#  'News',
#  'Reality-TV',
#  'Short',
#  'Talk-Show',
#  '\\N'}

# %%
genres = np.transpose(IMDB_movie_details_unique_tally)[0].tolist()
genres.sort()

keys = [_.lower() for _ in genres]
genres = dict(zip(genres, keys))
genres['Film-Noir'] = 'noir'
genres['Sci-Fi'] = 'scifi'
genres = {v:k for k, v in genres.items()}

genres, len(genres)
# Out:
# ({'action': 'Action',
#   'adventure': 'Adventure',
#   'animation': 'Animation',
#   'biography': 'Biography',
#   'comedy': 'Comedy',
#   'crime': 'Crime',
#   'drama': 'Drama',
#   'family': 'Family',
#   'fantasy': 'Fantasy',
#   'noir': 'Film-Noir',
#   'history': 'History',
#   'horror': 'Horror',
#   'music': 'Music',
#   'musical': 'Musical',
#   'mystery': 'Mystery',
#   'romance': 'Romance',
#   'scifi': 'Sci-Fi',
#   'sport': 'Sport',
#   'thriller': 'Thriller',
#   'war': 'War',
#   'western': 'Western'},
#  21)

# %% [markdown]
# ### Now we need to replace the genres in our dataset by 21 genres that we found. We can semiautomatize the process, however, a manual inspection and correction of the labels is done (example of such correction is 'Science fiction' that needed to be replaced by 'sci-fi')

# %%
genres_data_unique = set(np.concatenate(genres_data))
genres_data_unique = sorted([_.lower() for _ in genres_data_unique])

data2imdb = {_:','.join(sorted(set(re.findall(r'[\w]+', _)).intersection(set(genres.keys())))) for _ in genres_data_unique}

data2imdb
# Out:
# {'absurdism': '',
#  'acid western': 'western',
#  'action': 'action',
#  'action comedy': 'action,comedy',
#  'action thrillers': 'action',
#  'action/adventure': 'action,adventure',
#  'addiction drama': 'drama',
#  'adult': '',
#  'adventure': 'adventure',
#  'adventure comedy': 'adventure,comedy',
#  'airplanes and airports': '',
#  'albino bias': '',
#  'alien film': '',
#  'alien invasion': '',
#  'americana': '',
#  'animal picture': '',
#  'animals': '',
#  'animated cartoon': '',
#  'animated musical': 'musical',
#  'animation': 'animation',
#  'anime': '',
#  'anthology': '',
#  'anthropology': '',
#  'anti-war': 'war',
#  'anti-war film': 'war',
#  'apocalyptic and post-apocalyptic fiction': '',
#  'archaeology': '',
#  'archives and records': '',
#  'art film': '',
#  'auto racing': '',
#  'avant-garde': '',
#  'b-movie': '',
#  'b-western': 'western',
#  'backstage musical': 'musical',
#  'baseball': '',
#  'beach film': '',
#  'beach party film': '',
#  'bengali cinema': '',
#  'biker film': '',
#  'biographical film': '',
#  'biography': 'biography',
#  'biopic [feature]': '',
#  'black comedy': 'comedy',
#  'black-and-white': '',
#  'blaxploitation': '',
#  'bloopers & candid camera': '',
#  'bollywood': '',
#  'boxing': '',
#  'breakdance': '',
#  'british empire film': '',
#  'british new wave': '',
#  'bruceploitation': '',
#  'buddy cop': '',
#  'buddy film': '',
#  'buddy picture': '',
#  'business': '',
#  'c-movie': '',
#  'camp': '',
#  'caper story': '',
#  'cavalry film': '',
#  'chase movie': '',
#  'chick flick': '',
#  'childhood drama': 'drama',
#  "children's": '',
#  "children's entertainment": '',
#  "children's fantasy": 'fantasy',
#  "children's issues": '',
#  "children's/family": 'family',
#  'chinese movies': '',
#  'christian film': '',
#  'christmas movie': '',
#  'clay animation': 'animation',
#  'cold war': 'war',
#  'combat films': '',
#  'comdedy': '',
#  'comedy': 'comedy',
#  'comedy film': 'comedy',
#  'comedy horror': 'comedy,horror',
#  'comedy of errors': 'comedy',
#  'comedy of manners': 'comedy',
#  'comedy thriller': 'comedy,thriller',
#  'comedy western': 'comedy,western',
#  'comedy-drama': 'comedy,drama',
#  'coming of age': '',
#  'coming-of-age film': '',
#  'computer animation': 'animation',
#  'computers': '',
#  'concert film': '',
#  'conspiracy fiction': '',
#  'costume adventure': 'adventure',
#  'costume drama': 'drama',
#  'costume horror': 'horror',
#  'courtroom comedy': 'comedy',
#  'courtroom drama': 'drama',
#  'creature film': '',
#  'crime': 'crime',
#  'crime comedy': 'comedy,crime',
#  'crime drama': 'crime,drama',
#  'crime fiction': 'crime',
#  'crime thriller': 'crime,thriller',
#  'cult': '',
#  'culture & society': '',
#  'cyberpunk': '',
#  'czechoslovak new wave': '',
#  'dance': '',
#  'demonic child': '',
#  'detective': '',
#  'detective fiction': '',
#  'disaster': '',
#  'docudrama': '',
#  'documentary': '',
#  'dogme 95': '',
#  'domestic comedy': 'comedy',
#  'doomsday film': '',
#  'drama': 'drama',
#  'dystopia': '',
#  'ealing comedies': '',
#  'early black cinema': '',
#  'education': '',
#  'educational': '',
#  'ensemble film': '',
#  'environmental science': '',
#  'epic': '',
#  'epic western': 'western',
#  'erotic drama': 'drama',
#  'erotic thriller': 'thriller',
#  'erotica': '',
#  'escape film': '',
#  'essay film': '',
#  'existentialism': '',
#  'experimental film': '',
#  'exploitation': '',
#  'expressionism': '',
#  'extreme sports': '',
#  'fairy tale': '',
#  'family & personal relationships': 'family',
#  'family drama': 'drama,family',
#  'family film': 'family',
#  'family-oriented adventure': 'adventure,family',
#  'fan film': '',
#  'fantasy': 'fantasy',
#  'fantasy adventure': 'adventure,fantasy',
#  'fantasy comedy': 'comedy,fantasy',
#  'fantasy drama': 'drama,fantasy',
#  'feature film': '',
#  'female buddy film': '',
#  'feminist film': '',
#  'fictional film': '',
#  'filipino': '',
#  'filipino movies': '',
#  'film': '',
#  'film & television history': 'history',
#  'film adaptation': '',
#  'film noir': 'noir',
#  'film à clef': '',
#  'film-opera': '',
#  'filmed play': '',
#  'finance & investing': '',
#  'foreign legion': '',
#  'future noir': 'noir',
#  'gangster film': '',
#  'gay': '',
#  'gay interest': '',
#  'gay pornography': '',
#  'gay themed': '',
#  'gender issues': '',
#  'giallo': '',
#  'glamorized spy film': '',
#  'goat gland': '',
#  'gothic film': '',
#  'graphic & applied arts': '',
#  'gross out': '',
#  'gross-out film': '',
#  'gulf war': 'war',
#  'hagiography': '',
#  'hardcore pornography': '',
#  'haunted house film': '',
#  'health & fitness': '',
#  'heaven-can-wait fantasies': '',
#  'heavenly comedy': 'comedy',
#  'heist': '',
#  'hip hop movies': '',
#  'historical documentaries': '',
#  'historical drama': 'drama',
#  'historical epic': '',
#  'historical fiction': '',
#  'history': 'history',
#  'holiday film': '',
#  'homoeroticism': '',
#  'horror': 'horror',
#  'horror comedy': 'comedy,horror',
#  'horse racing': '',
#  'humour': '',
#  'hybrid western': 'western',
#  'illnesses & disabilities': '',
#  'indian western': 'western',
#  'indie': '',
#  'inspirational drama': 'drama',
#  'instrumental music': 'music',
#  'interpersonal relationships': '',
#  'inventions & innovations': '',
#  'japanese movies': '',
#  'journalism': '',
#  'jukebox musical': 'musical',
#  'jungle film': '',
#  'juvenile delinquency film': '',
#  'kafkaesque': '',
#  'kitchen sink realism': '',
#  'language & literature': '',
#  'latino': '',
#  'law & crime': 'crime',
#  'legal drama': 'drama',
#  'lgbt': '',
#  'libraries and librarians': '',
#  'linguistics': '',
#  'live action': 'action',
#  'malayalam cinema': '',
#  'marriage drama': 'drama',
#  'martial arts film': '',
#  'master criminal films': '',
#  'media satire': '',
#  'media studies': '',
#  'medical fiction': '',
#  'melodrama': '',
#  'mockumentary': '',
#  'mondo film': '',
#  'monster': '',
#  'monster movie': '',
#  'movie serial': '',
#  'movies about gladiators': '',
#  'mumblecore': '',
#  'music': 'music',
#  'musical': 'musical',
#  'musical comedy': 'comedy,musical',
#  'musical drama': 'drama,musical',
#  'mystery': 'mystery',
#  'mythological fantasy': 'fantasy',
#  'natural disaster': '',
#  'natural horror films': 'horror',
#  'nature': '',
#  'neo-noir': 'noir',
#  'neorealism': '',
#  'new hollywood': '',
#  'new queer cinema': '',
#  'news': '',
#  'ninja movie': '',
#  'northern': '',
#  'nuclear warfare': '',
#  'operetta': '',
#  'outlaw': '',
#  'outlaw biker film': '',
#  'parkour in popular culture': '',
#  'parody': '',
#  'patriotic film': '',
#  'period horror': 'horror',
#  'period piece': '',
#  'pinku eiga': '',
#  'plague': '',
#  'point of view shot': '',
#  'political cinema': '',
#  'political documetary': '',
#  'political drama': 'drama',
#  'political satire': '',
#  'political thriller': 'thriller',
#  'pornographic movie': '',
#  'pornography': '',
#  'pre-code': '',
#  'prison': '',
#  'prison escape': '',
#  'prison film': '',
#  'private military company': '',
#  'propaganda film': '',
#  'psycho-biddy': '',
#  'psychological horror': 'horror',
#  'psychological thriller': 'thriller',
#  'punk rock': '',
#  'race movie': '',
#  'reboot': '',
#  'religious film': '',
#  'remake': '',
#  'revenge': '',
#  'revisionist fairy tale': '',
#  'revisionist western': 'western',
#  'road movie': '',
#  'road-horror': 'horror',
#  'roadshow theatrical release': '',
#  'roadshow/carny': '',
#  'rockumentary': '',
#  'romance film': 'romance',
#  'romantic comedy': 'comedy',
#  'romantic drama': 'drama',
#  'romantic fantasy': 'fantasy',
#  'romantic thriller': 'thriller',
#  'samurai cinema': '',
#  'satire': '',
#  'school story': '',
#  'sci fi pictures original films': '',
#  'sci-fi adventure': 'adventure',
#  'sci-fi horror': 'horror',
#  'sci-fi thriller': 'thriller',
#  'science fiction': '',
#  'science fiction western': 'western',
#  'screwball comedy': 'comedy',
#  'sex comedy': 'comedy',
#  'sexploitation': '',
#  'short film': '',
#  'silent film': '',
#  'silhouette animation': 'animation',
#  'singing cowboy': '',
#  'slapstick': '',
#  'slasher': '',
#  'slice of life story': '',
#  'social issues': '',
#  'social problem film': '',
#  'softcore porn': '',
#  'space opera': '',
#  'space western': 'western',
#  'spaghetti western': 'western',
#  'splatter film': '',
#  'sponsored film': '',
#  'sports': '',
#  'spy': '',
#  'stand-up comedy': 'comedy',
#  'star vehicle': '',
#  'statutory rape': '',
#  'steampunk': '',
#  'stoner film': '',
#  'stop motion': '',
#  'superhero': '',
#  'superhero movie': '',
#  'supermarionation': '',
#  'supernatural': '',
#  'surrealism': '',
#  'suspense': '',
#  'swashbuckler films': '',
#  'sword and sandal': '',
#  'sword and sorcery': '',
#  'sword and sorcery films': '',
#  'tamil cinema': '',
#  'teen': '',
#  'television movie': '',
#  'the netherlands in world war ii': 'war',
#  'therimin music': 'music',
#  'thriller': 'thriller',
#  'time travel': '',
#  'tokusatsu': '',
#  'tollywood': '',
#  'tragedy': '',
#  'tragicomedy': '',
#  'travel': '',
#  'vampire movies': '',
#  'war effort': 'war',
#  'war film': 'war',
#  'werewolf fiction': '',
#  'western': 'western',
#  'whodunit': '',
#  'women in prison films': '',
#  'workplace comedy': 'comedy',
#  'world cinema': '',
#  'world history': 'history',
#  'wuxia': '',
#  'z movie': '',
#  'zombie film': ''}

# %%
data2imdb_mod = {'absurdism': '',
                 'acid western': 'western',
                 'action': 'action',
                 'action comedy': 'action,comedy',
                 'action thrillers': 'action,thriller', #
                 'action/adventure': 'action,adventure',
                 'addiction drama': 'drama',
                 'adult': '',
                 'adventure': 'adventure',
                 'adventure comedy': 'adventure,comedy',
                 'airplanes and airports': '',
                 'albino bias': '',
                 'alien film': 'scifi', #
                 'alien invasion': 'scifi', #
                 'americana': '',
                 'animal picture': '',
                 'animals': '',
                 'animated cartoon': 'animation', #
                 'animated musical': 'animation,musical', #
                 'animation': 'animation',
                 'anime': 'animation', #
                 'anthology': '',
                 'anthropology': '',
                 'anti-war': 'war',
                 'anti-war film': 'war',
                 'apocalyptic and post-apocalyptic fiction': '',
                 'archaeology': '',
                 'archives and records': '',
                 'art film': '',
                 'auto racing': '',
                 'avant-garde': '',
                 'b-movie': '',
                 'b-western': 'western',
                 'backstage musical': 'musical',
                 'baseball': '',
                 'beach film': '',
                 'beach party film': '',
                 'bengali cinema': '',
                 'biker film': '',
                 'biographical film': 'biography', #
                 'biography': 'biography',
                 'biopic [feature]': 'biography', #
                 'black comedy': 'comedy',
                 'black-and-white': '',
                 'blaxploitation': '',
                 'bloopers & candid camera': '',
                 'bollywood': '',
                 'boxing': '',
                 'breakdance': '',
                 'british empire film': '',
                 'british new wave': '',
                 'bruceploitation': '',
                 'buddy cop': '',
                 'buddy film': '',
                 'buddy picture': '',
                 'business': '',
                 'c-movie': '',
                 'camp': '',
                 'caper story': '',
                 'cavalry film': '',
                 'chase movie': '',
                 'chick flick': '',
                 'childhood drama': 'drama',
                 "children's": '',
                 "children's entertainment": '',
                 "children's fantasy": 'fantasy',
                 "children's issues": '',
                 "children's/family": 'family',
                 'chinese movies': '',
                 'christian film': '',
                 'christmas movie': '',
                 'clay animation': 'animation',
                 'cold war': 'war',
                 'combat films': '',
                 'comdedy': 'comedy', #
                 'comedy': 'comedy',
                 'comedy film': 'comedy',
                 'comedy horror': 'comedy,horror',
                 'comedy of errors': 'comedy',
                 'comedy of manners': 'comedy',
                 'comedy thriller': 'comedy,thriller',
                 'comedy western': 'comedy,western',
                 'comedy-drama': 'comedy,drama',
                 'coming of age': '',
                 'coming-of-age film': '',
                 'computer animation': 'animation',
                 'computers': '',
                 'concert film': '',
                 'conspiracy fiction': '',
                 'costume adventure': 'adventure',
                 'costume drama': 'drama',
                 'costume horror': 'horror',
                 'courtroom comedy': 'comedy',
                 'courtroom drama': 'drama',
                 'creature film': '',
                 'crime': 'crime',
                 'crime comedy': 'comedy,crime',
                 'crime drama': 'crime,drama',
                 'crime fiction': 'crime',
                 'crime thriller': 'crime,thriller',
                 'cult': '',
                 'culture & society': '',
                 'cyberpunk': '',
                 'czechoslovak new wave': '',
                 'dance': '',
                 'demonic child': '',
                 'detective': '',
                 'detective fiction': '',
                 'disaster': '',
                 'docudrama': '',
                 'documentary': '',
                 'dogme 95': '',
                 'domestic comedy': 'comedy',
                 'doomsday film': '',
                 'drama': 'drama',
                 'dystopia': '',
                 'ealing comedies': 'comedy', #
                 'early black cinema': '',
                 'education': '',
                 'educational': '',
                 'ensemble film': '',
                 'environmental science': '',
                 'epic': '',
                 'epic western': 'western',
                 'erotic drama': 'drama',
                 'erotic thriller': 'thriller',
                 'erotica': '',
                 'escape film': '',
                 'essay film': '',
                 'existentialism': '',
                 'experimental film': '',
                 'exploitation': '',
                 'expressionism': '',
                 'extreme sports': 'sport', #
                 'fairy tale': '',
                 'family & personal relationships': 'family',
                 'family drama': 'drama,family',
                 'family film': 'family',
                 'family-oriented adventure': 'adventure,family',
                 'fan film': '',
                 'fantasy': 'fantasy',
                 'fantasy adventure': 'adventure,fantasy',
                 'fantasy comedy': 'comedy,fantasy',
                 'fantasy drama': 'drama,fantasy',
                 'feature film': '',
                 'female buddy film': '',
                 'feminist film': '',
                 'fictional film': '',
                 'filipino': '',
                 'filipino movies': '',
                 'film': '',
                 'film & television history': 'history',
                 'film adaptation': '',
                 'film noir': 'noir',
                 'film à clef': '',
                 'film-opera': '',
                 'filmed play': '',
                 'finance & investing': '',
                 'foreign legion': '',
                 'future noir': 'noir',
                 'gangster film': '',
                 'gay': '',
                 'gay interest': '',
                 'gay pornography': '',
                 'gay themed': '',
                 'gender issues': '',
                 'giallo': '',
                 'glamorized spy film': '',
                 'goat gland': '',
                 'gothic film': '',
                 'graphic & applied arts': '',
                 'gross out': '',
                 'gross-out film': '',
                 'gulf war': 'war',
                 'hagiography': '',
                 'hardcore pornography': '',
                 'haunted house film': '',
                 'health & fitness': '',
                 'heaven-can-wait fantasies': '',
                 'heavenly comedy': 'comedy',
                 'heist': '',
                 'hip hop movies': '', 
                 'historical documentaries': 'history', #
                 'historical drama': 'drama,history', #
                 'historical epic': 'history', #
                 'historical fiction': 'history', #
                 'history': 'history',
                 'holiday film': '',
                 'homoeroticism': '',
                 'horror': 'horror',
                 'horror comedy': 'comedy,horror',
                 'horse racing': '',
                 'humour': '',
                 'hybrid western': 'western',
                 'illnesses & disabilities': '',
                 'indian western': 'western',
                 'indie': '',
                 'inspirational drama': 'drama',
                 'instrumental music': 'music',
                 'interpersonal relationships': '',
                 'inventions & innovations': '',
                 'japanese movies': '',
                 'journalism': '',
                 'jukebox musical': 'musical',
                 'jungle film': '',
                 'juvenile delinquency film': '',
                 'kafkaesque': '',
                 'kitchen sink realism': '',
                 'language & literature': '',
                 'latino': '',
                 'law & crime': 'crime',
                 'legal drama': 'drama',
                 'lgbt': '',
                 'libraries and librarians': '',
                 'linguistics': '',
                 'live action': 'action',
                 'malayalam cinema': '',
                 'marriage drama': 'drama',
                 'martial arts film': '',
                 'master criminal films': '',
                 'media satire': '',
                 'media studies': '',
                 'medical fiction': '',
                 'melodrama': '', 
                 'mockumentary': '',
                 'mondo film': '',
                 'monster': '',
                 'monster movie': '',
                 'movie serial': '',
                 'movies about gladiators': '',
                 'mumblecore': '',
                 'music': 'music',
                 'musical': 'musical',
                 'musical comedy': 'comedy,musical',
                 'musical drama': 'drama,musical',
                 'mystery': 'mystery',
                 'mythological fantasy': 'fantasy',
                 'natural disaster': '',
                 'natural horror films': 'horror',
                 'nature': '',
                 'neo-noir': 'noir',
                 'neorealism': '',
                 'new hollywood': '',
                 'new queer cinema': '',
                 'news': '',
                 'ninja movie': '',
                 'northern': '',
                 'nuclear warfare': '',
                 'operetta': '',
                 'outlaw': '',
                 'outlaw biker film': '',
                 'parkour in popular culture': '',
                 'parody': '',
                 'patriotic film': '',
                 'period horror': 'horror',
                 'period piece': '',
                 'pinku eiga': '',
                 'plague': '',
                 'point of view shot': '',
                 'political cinema': '',
                 'political documetary': '',
                 'political drama': 'drama',
                 'political satire': '',
                 'political thriller': 'thriller',
                 'pornographic movie': '',
                 'pornography': '',
                 'pre-code': '',
                 'prison': '',
                 'prison escape': '',
                 'prison film': '',
                 'private military company': '',
                 'propaganda film': '',
                 'psycho-biddy': '',
                 'psychological horror': 'horror',
                 'psychological thriller': 'thriller',
                 'punk rock': '',
                 'race movie': '',
                 'reboot': '',
                 'religious film': '',
                 'remake': '',
                 'revenge': '',
                 'revisionist fairy tale': '',
                 'revisionist western': 'western',
                 'road movie': '',
                 'road-horror': 'horror',
                 'roadshow theatrical release': '',
                 'roadshow/carny': '',
                 'rockumentary': '',
                 'romance film': 'romance',
                 'romantic comedy': 'comedy,romance', #
                 'romantic drama': 'drama,romance', #
                 'romantic fantasy': 'fantasy,romance', #
                 'romantic thriller': 'thriller,romance', #
                 'samurai cinema': '',
                 'satire': '',
                 'school story': '',
                 'sci fi pictures original films': 'scifi', #
                 'sci-fi adventure': 'adventure,scifi', #
                 'sci-fi horror': 'horror,scifi', #
                 'sci-fi thriller': 'scifi,thriller', #
                 'science fiction': 'scifi', #
                 'science fiction western': 'scifi,western', #
                 'screwball comedy': 'comedy',
                 'sex comedy': 'comedy',
                 'sexploitation': '',
                 'short film': '',
                 'silent film': '',
                 'silhouette animation': 'animation',
                 'singing cowboy': '',
                 'slapstick': 'comedy', #
                 'slasher': '',
                 'slice of life story': '',
                 'social issues': '',
                 'social problem film': '',
                 'softcore porn': '',
                 'space opera': '',
                 'space western': 'western',
                 'spaghetti western': 'western',
                 'splatter film': '',
                 'sponsored film': '',
                 'sports': 'sport', #
                 'spy': '',
                 'stand-up comedy': 'comedy',
                 'star vehicle': '',
                 'statutory rape': '',
                 'steampunk': '',
                 'stoner film': '',
                 'stop motion': '',
                 'superhero': '',
                 'superhero movie': '',
                 'supermarionation': '',
                 'supernatural': '',
                 'surrealism': '',
                 'suspense': '',
                 'swashbuckler films': '',
                 'sword and sandal': '',
                 'sword and sorcery': '',
                 'sword and sorcery films': '',
                 'tamil cinema': '',
                 'teen': '',
                 'television movie': '',
                 'the netherlands in world war ii': 'war',
                 'therimin music': 'music',
                 'thriller': 'thriller',
                 'time travel': 'scifi', #
                 'tokusatsu': '',
                 'tollywood': '',
                 'tragedy': 'drama', #
                 'tragicomedy': 'comedy,drama', #
                 'travel': '',
                 'vampire movies': '',
                 'war effort': 'war',
                 'war film': 'war',
                 'werewolf fiction': '',
                 'western': 'western',
                 'whodunit': '',
                 'women in prison films': '',
                 'workplace comedy': 'comedy',
                 'world cinema': '',
                 'world history': 'history',
                 'wuxia': '',
                 'z movie': '',
                 'zombie film': ''
                }

# %%
genres_data2 = []

for d in genres_data:
    
    d2 = [data2imdb_mod[_.lower()] for _ in d]
    
    d2 = sorted(set(','.join(d2).split(',')))
    
    d2 = [_ for _ in d2 if _!='']
    
    genres_data2.append(d2)


genres_data2
# Out:
# [['drama'],
#  ['action', 'adventure', 'drama', 'scifi'],
#  ['action', 'drama', 'musical'],
#  ['comedy'],
#  ['crime', 'drama'],
#  ['action', 'adventure', 'drama', 'thriller'],
#  ['drama', 'horror', 'thriller'],
#  ['drama'],
#  ['comedy', 'drama', 'romance'],
#  ['animation', 'family'],
#  ['comedy'],
#  ['comedy', 'crime', 'drama'],
#  ['comedy'],
#  ['action', 'adventure', 'drama', 'war'],
#  ['comedy'],
#  ['horror'],
#  ['comedy', 'crime', 'horror', 'mystery', 'thriller'],
#  ['drama'],
#  ['action', 'crime', 'romance', 'thriller'],
#  ['drama'],
#  ['drama', 'war'],
#  ['animation', 'family'],
#  ['drama'],
#  ['action', 'adventure', 'drama'],
#  ['drama'],
#  ['drama'],
#  ['comedy'],
#  ['comedy', 'romance'],
#  ['comedy', 'musical', 'romance'],
#  ['action', 'adventure', 'drama', 'history', 'romance'],
#  ['action', 'adventure', 'romance', 'thriller'],
#  ['biography', 'drama'],
#  ['drama', 'family'],
#  ['horror', 'mystery'],
#  ['action', 'adventure', 'drama', 'western'],
#  ['comedy', 'drama'],
#  ['animation', 'comedy', 'family'],
#  ['drama'],
#  [],
#  ['action', 'adventure', 'drama', 'history', 'war'],
#  ['action', 'adventure', 'comedy', 'western'],
#  ['crime', 'drama', 'mystery', 'thriller'],
#  [],
#  ['comedy', 'romance'],
#  ['comedy'],
#  ['drama'],
#  ['comedy'],
#  ['comedy', 'musical', 'romance'],
#  ['action', 'adventure', 'fantasy', 'romance'],
#  ['drama'],
#  ['animation', 'comedy', 'family'],
#  ['comedy'],
#  ['drama', 'romance'],
#  ['comedy', 'drama', 'fantasy', 'musical', 'romance'],
#  ['musical'],
#  ['drama'],
#  [],
#  [],
#  ['horror'],
#  ['drama', 'family', 'romance'],
#  ['comedy', 'drama', 'romance'],
#  ['musical'],
#  ['animation', 'comedy', 'family'],
#  ['action', 'adventure', 'horror', 'thriller'],
#  ['action'],
#  ['drama', 'romance'],
#  ['drama'],
#  ['comedy'],
#  ['drama'],
#  ['horror', 'thriller'],
#  [],
#  ['comedy', 'drama'],
#  ['drama', 'sport'],
#  ['drama'],
#  ['adventure', 'animation', 'family', 'music'],
#  ['comedy', 'fantasy'],
#  ['crime', 'horror', 'mystery', 'thriller'],
#  ['action', 'adventure', 'western'],
#  ['drama'],
#  ['drama', 'fantasy', 'mystery', 'romance'],
#  ['drama'],
#  ['scifi'],
#  ['action', 'adventure', 'crime', 'drama', 'thriller'],
#  ['comedy', 'drama', 'romance'],
#  ['animation', 'comedy', 'family'],
#  ['drama', 'war'],
#  ['action', 'adventure'],
#  ['drama', 'musical', 'romance'],
#  ['biography', 'drama', 'history', 'war'],
#  ['action', 'adventure', 'drama', 'thriller'],
#  ['crime', 'mystery', 'thriller'],
#  ['drama', 'musical'],
#  ['action', 'fantasy', 'scifi', 'thriller'],
#  ['drama', 'romance'],
#  ['comedy', 'drama', 'romance'],
#  ['comedy', 'drama', 'musical', 'mystery', 'romance', 'thriller'],
#  ['comedy', 'romance'],
#  ['animation', 'fantasy', 'horror'],
#  ['drama', 'war'],
#  ['action', 'adventure', 'crime', 'thriller'],
#  ['comedy', 'crime', 'drama', 'noir', 'thriller'],
#  ['drama'],
#  ['comedy'],
#  ['action', 'adventure', 'fantasy', 'thriller'],
#  ['drama', 'romance'],
#  ['drama'],
#  ['crime', 'drama'],
#  ['comedy'],
#  ['drama'],
#  ['comedy', 'crime', 'drama'],
#  ['comedy'],
#  ['thriller'],
#  ['action', 'adventure', 'drama', 'romance', 'thriller'],
#  ['musical'],
#  ['comedy'],
#  ['action', 'adventure'],
#  ['mystery', 'thriller'],
#  ['crime', 'drama', 'noir', 'thriller'],
#  ['drama', 'romance'],
#  ['drama', 'history'],
#  ['comedy', 'drama'],
#  ['comedy'],
#  ['comedy', 'romance'],
#  ['adventure', 'fantasy'],
#  ['comedy', 'drama'],
#  ['comedy', 'family'],
#  ['crime', 'drama', 'thriller'],
#  ['action', 'comedy', 'horror', 'scifi'],
#  ['comedy', 'drama', 'romance'],
#  ['horror', 'scifi', 'thriller'],
#  ['drama'],
#  ['action', 'adventure', 'horror', 'scifi', 'thriller'],
#  ['drama', 'romance'],
#  ['western'],
#  ['crime', 'drama', 'romance', 'thriller'],
#  ['crime', 'drama', 'mystery', 'thriller'],
#  ['comedy', 'horror', 'musical'],
#  [],
#  ['action', 'comedy', 'crime', 'drama'],
#  ['comedy', 'family'],
#  ['drama'],
#  ['horror', 'scifi'],
#  ['biography', 'comedy', 'drama', 'romance'],
#  [],
#  ['horror'],
#  ['comedy', 'drama'],
#  ['drama', 'horror', 'romance'],
#  ['drama'],
#  ['drama', 'romance'],
#  ['comedy'],
#  ['crime', 'drama', 'thriller'],
#  [],
#  ['action', 'adventure', 'drama', 'romance', 'western'],
#  ['drama', 'romance'],
#  ['drama', 'horror', 'thriller'],
#  ['drama', 'romance', 'war'],
#  ['drama'],
#  ['comedy', 'crime'],
#  ['western'],
#  ['adventure', 'animation', 'comedy', 'family'],
#  ['action', 'crime', 'drama'],
#  ['family', 'musical'],
#  ['drama', 'romance'],
#  [],
#  ['drama'],
#  ['comedy'],
#  ['scifi'],
#  ['crime', 'drama', 'mystery', 'romance'],
#  ['comedy'],
#  ['animation', 'fantasy', 'scifi'],
#  ['action', 'mystery', 'western'],
#  ['action', 'adventure', 'drama', 'western'],
#  ['crime', 'mystery'],
#  ['thriller'],
#  ['drama'],
#  [],
#  ['drama'],
#  ['horror', 'thriller'],
#  ['action', 'adventure', 'crime', 'drama', 'thriller'],
#  ['drama'],
#  ['action'],
#  ['drama'],
#  ['drama'],
#  ['comedy'],
#  ['comedy', 'romance'],
#  ['action', 'drama', 'thriller'],
#  ['comedy'],
#  ['comedy', 'mystery', 'thriller'],
#  ['horror'],
#  ['drama', 'sport', 'thriller'],
#  ['action', 'adventure', 'thriller'],
#  ['drama', 'romance'],
#  ['animation', 'comedy', 'family'],
#  ['comedy', 'romance'],
#  ['horror', 'thriller'],
#  ['crime', 'thriller'],
#  ['animation', 'comedy', 'family'],
#  ['action', 'adventure'],
#  ['drama'],
#  ['animation', 'musical'],
#  ['comedy', 'crime'],
#  ['drama'],
#  ['comedy'],
#  ['comedy', 'family'],
#  ['drama'],
#  ['crime', 'drama', 'family', 'mystery', 'noir', 'romance'],
#  ['crime', 'drama'],
#  ['drama', 'romance'],
#  ['crime', 'drama', 'thriller'],
#  ['comedy'],
#  ['action', 'adventure', 'crime', 'thriller'],
#  [],
#  ['action', 'adventure', 'comedy', 'fantasy', 'scifi'],
#  ['comedy', 'family', 'fantasy'],
#  ['drama', 'romance'],
#  ['animation', 'family', 'musical'],
#  ['horror'],
#  ['drama'],
#  ['crime', 'mystery', 'thriller'],
#  ['horror'],
#  ['action', 'adventure', 'crime', 'thriller'],
#  ['comedy', 'romance'],
#  ['drama', 'musical', 'romance', 'war'],
#  ['adventure', 'comedy', 'family'],
#  ['comedy', 'crime', 'drama'],
#  ['comedy', 'drama', 'romance'],
#  ['action', 'adventure', 'animation', 'family', 'fantasy', 'scifi'],
#  ['horror'],
#  ['comedy', 'romance'],
#  ['crime', 'drama', 'horror', 'thriller'],
#  ['action', 'adventure', 'drama'],
#  ['comedy', 'drama', 'romance'],
#  ['drama'],
#  ['war'],
#  ['comedy'],
#  [],
#  ['drama', 'noir'],
#  ['drama'],
#  ['adventure', 'scifi'],
#  ['action', 'adventure', 'western'],
#  ['horror'],
#  [],
#  ['comedy'],
#  ['romance'],
#  ['action', 'crime', 'drama'],
#  ['comedy'],
#  ['drama'],
#  ['action', 'drama'],
#  ['drama', 'family'],
#  ['horror'],
#  ['action', 'drama', 'horror'],
#  ['action', 'adventure', 'crime', 'thriller'],
#  ['comedy', 'fantasy', 'scifi'],
#  ['romance'],
#  ['comedy', 'drama', 'romance'],
#  ['drama'],
#  ['comedy', 'drama'],
#  ['comedy'],
#  ['comedy'],
#  ['crime', 'drama', 'thriller'],
#  ['action', 'adventure', 'comedy', 'romance'],
#  ['crime', 'drama', 'thriller'],
#  ['thriller'],
#  ['drama'],
#  ['crime', 'thriller'],
#  ['comedy'],
#  ['animation'],
#  ['horror', 'thriller'],
#  ['action', 'drama', 'thriller', 'war'],
#  ['comedy', 'romance'],
#  ['comedy', 'horror', 'scifi'],
#  ['drama'],
#  ['drama', 'sport'],
#  ['comedy'],
#  ['drama'],
#  [],
#  ['drama'],
#  ['comedy', 'crime', 'drama', 'mystery', 'thriller'],
#  ['comedy'],
#  ['action', 'drama', 'mystery', 'romance', 'thriller'],
#  ['drama'],
#  ['animation', 'comedy', 'family'],
#  ['comedy'],
#  [],
#  ['drama', 'musical'],
#  [],
#  ['adventure', 'comedy', 'family', 'music', 'romance'],
#  ['comedy', 'drama', 'romance'],
#  ['comedy', 'drama', 'romance'],
#  ['comedy'],
#  ['action', 'adventure', 'comedy', 'crime'],
#  [],
#  ['drama', 'music', 'romance'],
#  ['scifi'],
#  ['comedy', 'musical', 'romance'],
#  ['drama'],
#  [],
#  ['comedy', 'crime'],
#  ['drama', 'family'],
#  ['comedy'],
#  ['action', 'adventure', 'western'],
#  ['drama', 'romance'],
#  ['crime', 'drama'],
#  ['adventure', 'animation', 'comedy', 'family', 'fantasy', 'scifi', 'sport'],
#  ['animation', 'comedy', 'family'],
#  ['adventure', 'drama', 'romance', 'thriller'],
#  ['horror', 'thriller'],
#  ['action', 'adventure', 'comedy'],
#  ['comedy', 'drama', 'musical'],
#  ['drama', 'romance'],
#  ['action', 'crime', 'drama', 'mystery', 'romance'],
#  ['comedy'],
#  ['crime'],
#  ['comedy', 'drama', 'musical', 'romance'],
#  ['crime', 'drama', 'musical', 'romance'],
#  [],
#  ['comedy', 'family'],
#  ['animation', 'comedy'],
#  [],
#  [],
#  ['action', 'romance'],
#  ['comedy', 'family'],
#  ['comedy', 'drama'],
#  ['romance'],
#  ['drama', 'romance'],
#  ['animation', 'drama', 'romance'],
#  ['comedy', 'romance'],
#  ['comedy', 'drama'],
#  ['animation', 'comedy', 'western'],
#  ['action', 'adventure', 'animation', 'family', 'fantasy'],
#  ['drama'],
#  [],
#  ['drama', 'musical', 'romance'],
#  ['animation', 'comedy'],
#  ['comedy', 'horror', 'scifi'],
#  ['comedy', 'romance'],
#  ['action', 'drama', 'romance', 'sport'],
#  ['adventure', 'drama', 'romance', 'war'],
#  ['comedy', 'drama', 'family'],
#  ['comedy', 'romance'],
#  ['action', 'animation', 'comedy'],
#  ['comedy', 'drama', 'romance'],
#  ['drama'],
#  ['drama'],
#  ['crime', 'drama', 'mystery', 'thriller'],
#  ['action', 'comedy', 'crime'],
#  ['action', 'drama', 'western'],
#  ['comedy', 'drama'],
#  ['animation'],
#  ['comedy', 'drama'],
#  [],
#  ['comedy', 'drama', 'musical', 'romance'],
#  ['comedy', 'drama', 'family'],
#  ['crime', 'thriller'],
#  ['adventure', 'drama', 'war'],
#  [],
#  ['comedy', 'drama', 'scifi'],
#  ['action', 'adventure', 'thriller'],
#  ['action', 'adventure', 'animation', 'scifi', 'thriller'],
#  ['comedy', 'family', 'fantasy', 'romance'],
#  ['drama'],
#  ['comedy', 'drama', 'family'],
#  ['comedy', 'horror', 'mystery', 'thriller'],
#  ['action', 'crime'],
#  ['comedy'],
#  ['drama'],
#  ['comedy', 'musical'],
#  ['action', 'war'],
#  ['drama'],
#  [],
#  ['comedy'],
#  [],
#  ['action', 'comedy'],
#  ['comedy', 'thriller'],
#  ['comedy', 'drama', 'romance'],
#  ['action', 'adventure', 'comedy', 'western'],
#  [],
#  [],
#  ['drama', 'romance'],
#  ['drama'],
#  ['comedy', 'drama', 'family', 'musical'],
#  ['comedy', 'romance'],
#  ['drama'],
#  ['drama', 'fantasy', 'mystery', 'romance', 'thriller'],
#  ['drama'],
#  [],
#  ['drama', 'musical', 'romance'],
#  [],
#  ['drama', 'romance'],
#  ['mystery', 'noir', 'thriller'],
#  ['drama'],
#  ['horror', 'scifi'],
#  ['drama'],
#  ['comedy'],
#  ['comedy', 'romance'],
#  ['drama', 'musical'],
#  ['drama'],
#  [],
#  ['crime', 'drama'],
#  ['crime', 'thriller'],
#  ['crime', 'drama', 'romance'],
#  ['drama'],
#  ['drama'],
#  ['action', 'comedy', 'drama', 'romance'],
#  ['scifi'],
#  ['comedy', 'sport'],
#  ['animation'],
#  ['action', 'adventure', 'drama', 'history', 'musical', 'romance', 'war'],
#  ['comedy'],
#  ['drama'],
#  ['animation', 'comedy'],
#  ['comedy'],
#  ['comedy', 'horror'],
#  ['action', 'adventure', 'comedy'],
#  ['adventure', 'comedy', 'family'],
#  ['animation', 'comedy'],
#  ['comedy', 'war'],
#  ['action', 'comedy', 'musical'],
#  ['comedy', 'romance'],
#  ['drama'],
#  ['adventure'],
#  ['drama', 'family'],
#  ['action', 'comedy', 'crime', 'romance'],
#  ['comedy'],
#  ['comedy', 'drama', 'fantasy', 'horror', 'mystery'],
#  ['thriller'],
#  ['crime', 'drama', 'mystery', 'thriller'],
#  ['comedy', 'romance'],
#  ['comedy'],
#  ['biography'],
#  ['drama', 'musical'],
#  ['crime', 'history'],
#  ['comedy', 'drama'],
#  [],
#  ['crime', 'drama', 'mystery', 'thriller'],
#  [],
#  ['animation', 'comedy', 'family'],
#  ['comedy', 'crime', 'romance'],
#  ['comedy', 'romance'],
#  ['animation', 'comedy'],
#  ['comedy'],
#  ['comedy', 'romance'],
#  ['comedy', 'scifi'],
#  ['comedy'],
#  ['comedy', 'drama', 'romance'],
#  ['drama'],
#  ['animation', 'comedy', 'family'],
#  ['crime', 'drama'],
#  ['thriller'],
#  ['drama'],
#  ['drama', 'mystery'],
#  ['drama', 'romance'],
#  ['action', 'drama'],
#  ['drama'],
#  ['drama', 'musical', 'romance'],
#  [],
#  ['horror'],
#  ['horror', 'scifi', 'thriller'],
#  ['action', 'adventure', 'horror', 'scifi'],
#  ['action', 'scifi', 'thriller'],
#  ['drama', 'romance', 'war'],
#  ['adventure', 'comedy', 'drama'],
#  ['horror', 'thriller'],
#  ['drama', 'romance'],
#  ['horror'],
#  ['romance'],
#  ['action', 'adventure', 'drama', 'fantasy'],
#  ['comedy', 'drama'],
#  ['drama', 'romance'],
#  ['drama', 'romance'],
#  ['crime', 'drama'],
#  ['comedy', 'drama'],
#  ['crime', 'drama', 'family', 'thriller'],
#  ['drama', 'noir', 'romance'],
#  ['action', 'crime', 'thriller'],
#  ['drama'],
#  ['horror'],
#  ['horror'],
#  ['action', 'adventure'],
#  ['adventure', 'animation', 'fantasy'],
#  ['comedy', 'crime', 'drama'],
#  ['action', 'adventure', 'drama', 'western'],
#  ['drama', 'family'],
#  ['comedy'],
#  ['action', 'adventure', 'comedy', 'western'],
#  ['crime', 'drama'],
#  ['crime', 'horror', 'mystery', 'thriller'],
#  ['horror', 'mystery'],
#  ['animation', 'family', 'fantasy'],
#  ['action', 'adventure', 'crime', 'drama', 'mystery', 'thriller'],
#  ['comedy', 'drama'],
#  ['adventure'],
#  ['drama'],
#  ['scifi'],
#  ['comedy', 'drama', 'musical'],
#  ['romance'],
#  ['action', 'adventure', 'western'],
#  [],
#  ['drama'],
#  ['animation', 'scifi'],
#  ['action', 'adventure', 'scifi'],
#  ['drama', 'scifi'],
#  ['comedy', 'drama'],
#  ['mystery', 'noir'],
#  ['family'],
#  ['comedy', 'family', 'musical', 'romance'],
#  ['drama', 'romance'],
#  ['comedy'],
#  ['crime', 'drama'],
#  ['crime', 'drama', 'noir', 'thriller'],
#  ['adventure', 'animation', 'family'],
#  ['comedy', 'drama', 'family', 'fantasy', 'romance', 'scifi'],
#  ['animation', 'comedy', 'family'],
#  ['crime', 'drama', 'horror', 'thriller'],
#  ['comedy'],
#  ['comedy'],
#  ['drama'],
#  ['comedy', 'musical'],
#  ['comedy', 'crime', 'drama', 'fantasy', 'scifi', 'thriller'],
#  ['comedy', 'horror'],
#  ['comedy', 'sport'],
#  ['action', 'adventure', 'crime', 'drama', 'thriller'],
#  ['drama', 'romance'],
#  ['horror'],
#  ['drama', 'romance'],
#  [],
#  ['scifi'],
#  ['family'],
#  ['comedy', 'fantasy', 'horror'],
#  ['history', 'music'],
#  ['drama', 'family', 'musical'],
#  ['comedy', 'family'],
#  ['romance'],
#  ['horror'],
#  ['biography', 'drama', 'history'],
#  [],
#  ['biography', 'crime', 'drama'],
#  ['comedy', 'music'],
#  ['comedy', 'horror', 'musical', 'western'],
#  ['drama'],
#  ['drama', 'fantasy', 'romance'],
#  ['drama', 'romance'],
#  ['horror'],
#  ['scifi'],
#  ['drama'],
#  ['action', 'drama'],
#  ['comedy', 'western'],
#  ['comedy', 'drama'],
#  ['comedy', 'horror'],
#  [],
#  ['adventure', 'family'],
#  ['drama', 'romance'],
#  ['comedy', 'drama'],
#  ['comedy', 'family'],
#  ['adventure', 'drama', 'history'],
#  ['adventure', 'animation', 'family', 'fantasy'],
#  ['crime', 'horror', 'scifi', 'thriller'],
#  ['crime', 'drama', 'mystery', 'thriller'],
#  ['action', 'adventure', 'biography', 'drama'],
#  ['adventure', 'comedy', 'drama', 'family'],
#  ['horror'],
#  ['drama'],
#  [],
#  ['animation', 'family'],
#  ['comedy'],
#  ['drama', 'family'],
#  ['drama', 'thriller'],
#  ['drama'],
#  ['drama'],
#  ['adventure', 'family'],
#  ['action', 'drama', 'romance'],
#  ['action', 'adventure', 'western'],
#  ['comedy'],
#  ['horror', 'thriller'],
#  ['drama', 'family', 'romance'],
#  ['crime', 'drama', 'mystery', 'thriller'],
#  ['action', 'horror', 'scifi', 'thriller'],
#  ['action', 'adventure', 'thriller'],
#  ['drama'],
#  ['comedy', 'family', 'scifi'],
#  ['horror', 'thriller'],
#  ['comedy', 'horror', 'mystery', 'scifi'],
#  ['action'],
#  ['comedy', 'drama'],
#  ['crime', 'drama'],
#  ['comedy', 'drama'],
#  ['horror', 'thriller'],
#  ['action', 'adventure', 'drama', 'western'],
#  ['animation'],
#  ['romance'],
#  ['drama'],
#  ['action', 'adventure', 'horror', 'scifi'],
#  ['crime', 'thriller'],
#  [],
#  [],
#  ['drama'],
#  ['crime', 'drama', 'thriller'],
#  ['drama', 'romance'],
#  ['adventure', 'animation', 'comedy', 'family', 'scifi'],
#  ['drama', 'romance'],
#  ['adventure', 'animation', 'comedy', 'family', 'fantasy'],
#  ['drama'],
#  ['comedy', 'drama', 'musical', 'romance'],
#  ['comedy', 'drama', 'family', 'musical', 'romance'],
#  ['biography'],
#  ['biography', 'drama', 'romance'],
#  ['comedy', 'drama', 'romance'],
#  ['drama', 'musical', 'romance'],
#  ['action', 'romance', 'western'],
#  ['drama'],
#  ['crime', 'mystery', 'thriller'],
#  ['crime', 'history'],
#  ['drama', 'romance', 'war'],
#  ['drama'],
#  ['drama', 'fantasy'],
#  ['comedy', 'romance'],
#  ['mystery', 'thriller'],
#  ['comedy', 'drama', 'romance'],
#  ['action', 'drama', 'war'],
#  ['action', 'adventure', 'comedy'],
#  ['adventure', 'animation', 'romance'],
#  ['action', 'drama', 'romance'],
#  ['drama'],
#  ['drama', 'horror', 'mystery', 'thriller'],
#  ['drama'],
#  ['drama'],
#  ['drama', 'war'],
#  ['drama', 'family', 'fantasy'],
#  ['drama'],
#  ['comedy', 'fantasy', 'romance', 'sport'],
#  ['action', 'adventure', 'animation', 'drama', 'fantasy', 'scifi'],
#  ['comedy', 'drama', 'romance'],
#  [],
#  ['drama'],
#  ['comedy', 'drama', 'musical', 'romance'],
#  ['horror', 'scifi'],
#  ['comedy'],
#  ['comedy'],
#  ['adventure', 'drama', 'war'],
#  ['animation', 'family', 'fantasy'],
#  ['drama', 'sport'],
#  ['drama'],
#  ['comedy', 'horror'],
#  ['drama'],
#  ['drama', 'romance'],
#  ['horror'],
#  ['action', 'crime', 'drama'],
#  ['comedy', 'musical'],
#  [],
#  ['drama', 'thriller'],
#  ['action', 'adventure', 'thriller'],
#  [],
#  ['comedy'],
#  ['action', 'adventure', 'biography', 'drama', 'history', 'war'],
#  ['action', 'drama', 'romance'],
#  ['comedy'],
#  ['drama', 'horror'],
#  ['action', 'adventure', 'comedy', 'crime', 'drama', 'romance', 'thriller'],
#  ['drama', 'romance'],
#  ['crime', 'drama', 'noir'],
#  ['comedy'],
#  ['adventure', 'drama', 'family'],
#  ['comedy'],
#  ['action', 'adventure', 'drama', 'musical', 'romance', 'thriller'],
#  ['action', 'adventure', 'western'],
#  ['action', 'adventure'],
#  ['crime', 'drama', 'thriller'],
#  ['crime', 'drama', 'romance'],
#  ['animation', 'scifi'],
#  ['comedy', 'drama', 'romance'],
#  ['animation'],
#  ['comedy', 'musical', 'romance'],
#  ['biography', 'crime', 'drama'],
#  ['crime', 'drama', 'thriller'],
#  ['crime'],
#  ['drama'],
#  [],
#  ['horror'],
#  ['comedy', 'drama', 'romance'],
#  ['horror', 'mystery', 'thriller'],
#  ['drama'],
#  ['comedy', 'drama', 'romance'],
#  ['action', 'adventure', 'drama', 'thriller', 'war'],
#  [],
#  ['comedy', 'family'],
#  ['comedy'],
#  ['drama', 'musical'],
#  ['action', 'comedy', 'drama', 'romance', 'western'],
#  ['adventure', 'family', 'fantasy'],
#  ['horror'],
#  ['drama'],
#  ['comedy', 'drama'],
#  ['animation', 'drama', 'fantasy', 'music', 'romance', 'scifi'],
#  ['drama', 'romance', 'thriller'],
#  ['crime', 'drama', 'thriller'],
#  ['crime', 'drama', 'musical'],
#  ['family', 'fantasy', 'scifi'],
#  ['musical'],
#  ['animation', 'comedy', 'family'],
#  ['drama', 'romance'],
#  ['action', 'adventure', 'crime', 'drama', 'thriller'],
#  ['drama', 'musical', 'romance'],
#  ['adventure'],
#  ['action', 'adventure'],
#  ['drama', 'thriller'],
#  ['drama'],
#  ['drama', 'romance'],
#  ['drama'],
#  ['drama', 'music'],
#  ['drama', 'romance'],
#  ['horror'],
#  ['drama'],
#  ['comedy', 'crime'],
#  ['comedy', 'family'],
#  ['comedy', 'scifi'],
#  ['crime', 'drama', 'thriller'],
#  ['drama', 'history', 'war'],
#  ['western'],
#  ['drama'],
#  ['drama', 'family'],
#  ['action', 'adventure', 'comedy'],
#  ['comedy'],
#  ['comedy', 'musical'],
#  [],
#  ['adventure', 'drama', 'family'],
#  ['history'],
#  ['comedy', 'crime', 'drama'],
#  ['fantasy'],
#  ['crime', 'drama', 'mystery', 'thriller'],
#  ['comedy', 'mystery'],
#  ['drama'],
#  ['drama', 'family'],
#  ['crime', 'horror', 'scifi', 'thriller'],
#  ['action', 'adventure', 'fantasy', 'romance'],
#  ['drama'],
#  ['drama', 'romance'],
#  ['comedy'],
#  ['comedy', 'musical'],
#  [],
#  ['comedy', 'drama'],
#  ['action', 'comedy', 'horror'],
#  ['drama', 'romance'],
#  ['action', 'adventure', 'drama', 'thriller'],
#  ['action', 'adventure', 'comedy'],
#  [],
#  ['drama', 'romance'],
#  ['comedy'],
#  ['action', 'adventure', 'comedy', 'thriller'],
#  ['action', 'adventure', 'western'],
#  ['comedy', 'sport'],
#  ['romance'],
#  ['comedy', 'drama', 'romance'],
#  ['crime', 'drama', 'mystery', 'thriller'],
#  ['drama'],
#  ['horror'],
#  [],
#  ['adventure'],
#  [],
#  ['animation', 'fantasy'],
#  ['drama'],
#  ['family', 'fantasy', 'musical'],
#  ['comedy'],
#  ['comedy', 'crime', 'drama', 'thriller'],
#  ['comedy', 'drama', 'family'],
#  ['drama'],
#  ['comedy', 'crime', 'drama', 'romance', 'thriller'],
#  ['horror', 'thriller'],
#  ['action'],
#  ['comedy', 'drama', 'horror', 'musical'],
#  ['crime', 'drama', 'scifi'],
#  ['musical'],
#  ['comedy'],
#  ['action', 'thriller', 'war'],
#  ['drama', 'history'],
#  ['drama'],
#  ['action', 'adventure', 'war', 'western'],
#  ['animation'],
#  ['drama'],
#  ['comedy'],
#  ['action', 'adventure', 'drama'],
#  ['action', 'adventure', 'scifi'],
#  ['comedy', 'musical'],
#  ['animation'],
#  ['comedy', 'fantasy', 'romance'],
#  ['drama', 'musical', 'romance'],
#  ['comedy', 'sport'],
#  ['comedy', 'crime', 'drama', 'horror', 'mystery', 'thriller'],
#  ['comedy'],
#  ['crime', 'thriller'],
#  ['horror'],
#  ['crime', 'drama', 'mystery', 'thriller'],
#  ['drama', 'romance'],
#  ['comedy'],
#  ['comedy'],
#  ['drama'],
#  ['animation'],
#  ['action', 'adventure', 'comedy', 'sport'],
#  ['drama'],
#  ['comedy', 'romance'],
#  ['crime', 'drama', 'thriller'],
#  ['action', 'crime', 'scifi', 'thriller'],
#  ['drama'],
#  ['adventure'],
#  ['animation', 'music'],
#  ['comedy', 'drama'],
#  ['action', 'adventure', 'scifi', 'thriller'],
#  ['horror', 'thriller'],
#  ['action', 'drama'],
#  ['action', 'adventure', 'western'],
#  ['crime'],
#  ['drama', 'mystery', 'thriller'],
#  ['action', 'adventure'],
#  ['action', 'comedy'],
#  ['drama'],
#  ['drama'],
#  ['action', 'adventure', 'comedy', 'drama'],
#  ['drama', 'romance'],
#  ['action', 'drama', 'romance', 'war'],
#  ['drama'],
#  ['drama'],
#  ['action', 'adventure', 'crime'],
#  ['animation', 'family'],
#  ['drama', 'history', 'war'],
#  ['action', 'adventure'],
#  ['comedy', 'drama'],
#  ['comedy'],
#  ['action', 'adventure', 'crime', 'thriller'],
#  ['comedy', 'romance'],
#  ['drama'],
#  ['drama'],
#  ['action', 'adventure', 'thriller'],
#  ['action', 'drama', 'thriller'],
#  ['drama'],
#  ['comedy'],
#  ['drama', 'thriller', 'war'],
#  ['comedy'],
#  ['drama'],
#  ['comedy', 'romance'],
#  ['comedy', 'crime', 'drama', 'thriller'],
#  [],
#  ['drama', 'war'],
#  ['comedy'],
#  ['action', 'adventure', 'scifi', 'thriller'],
#  ['crime', 'thriller'],
#  ['adventure', 'animation', 'family'],
#  ['comedy'],
#  ['horror'],
#  ['comedy', 'romance'],
#  ['biography', 'sport'],
#  ['comedy'],
#  ['action'],
#  ['action', 'adventure', 'comedy', 'family', 'fantasy', 'scifi'],
#  ['drama'],
#  ['action', 'adventure', 'crime', 'drama', 'mystery', 'romance', 'thriller'],
#  ['animation', 'family', 'fantasy', 'music', 'musical'],
#  ['adventure', 'horror', 'scifi'],
#  ['crime', 'mystery', 'thriller'],
#  ['comedy', 'horror'],
#  ['drama'],
#  ['action', 'adventure', 'drama', 'thriller'],
#  ['drama', 'horror', 'musical'],
#  ['comedy', 'romance'],
#  ['western'],
#  ['biography', 'crime', 'drama', 'horror', 'mystery', 'thriller'],
#  ['drama', 'fantasy', 'history', 'mystery'],
#  ['comedy', 'musical'],
#  ['comedy', 'mystery'],
#  ['action', 'crime', 'drama', 'mystery', 'thriller'],
#  ['comedy', 'horror', 'thriller'],
#  ['drama'],
#  ['animation', 'comedy', 'fantasy'],
#  ['animation'],
#  ['drama', 'war'],
#  ['adventure', 'animation', 'family'],
#  ['action'],
#  ['horror'],
#  ['comedy', 'drama', 'romance', 'war'],
#  ['horror', 'thriller'],
#  [],
#  ['drama'],
#  ['crime', 'drama', 'thriller'],
#  ['comedy', 'romance'],
#  ['drama'],
#  ['animation'],
#  ['adventure', 'family'],
#  [],
#  ['crime', 'drama', 'thriller'],
#  ['fantasy'],
#  ['comedy'],
#  ['comedy', 'romance'],
#  ['comedy', 'crime', 'drama'],
#  ['action', 'adventure', 'crime', 'mystery', 'thriller'],
#  ['drama', 'war'],
#  ['action'],
#  ['scifi'],
#  ['drama', 'musical'],
#  [],
#  ['comedy'],
#  ['action', 'crime', 'drama', 'thriller'],
#  [],
#  ['crime', 'horror', 'thriller'],
#  ['drama', 'thriller'],
#  ['comedy', 'horror', 'scifi'],
#  ['comedy', 'drama', 'romance'],
#  ['comedy'],
#  ['scifi'],
#  [],
#  ['action', 'adventure', 'crime', 'drama', 'thriller'],
#  ['comedy', 'drama', 'romance'],
#  ['drama', 'musical', 'romance'],
#  ['drama'],
#  ['action', 'thriller'],
#  ['horror'],
#  ['crime', 'drama', 'musical'],
#  ['comedy', 'drama', 'romance'],
#  ['comedy', 'drama', 'romance'],
#  ['action', 'adventure', 'drama', 'scifi', 'thriller'],
#  ['drama', 'family', 'history', 'musical'],
#  ['drama', 'mystery'],
#  ['horror'],
#  ['drama', 'horror', 'thriller'],
#  ['action', 'adventure', 'drama', 'romance'],
#  ['comedy', 'war'],
#  ['family', 'thriller'],
#  ['action', 'adventure', 'comedy', 'crime'],
#  ['action'],
#  ['comedy', 'drama'],
#  ['drama', 'history', 'war'],
#  ['crime', 'drama'],
#  ['action', 'thriller'],
#  [],
#  ['romance'],
#  ['drama', 'thriller'],
#  ['comedy', 'drama', 'romance'],
#  ['adventure', 'comedy', 'family'],
#  [],
#  ['action', 'crime', 'drama', 'romance', 'thriller', 'war'],
#  ['drama', 'romance'],
#  ['drama', 'romance'],
#  ['action', 'crime', 'mystery'],
#  ['comedy', 'romance'],
#  ['adventure', 'drama'],
#  ['drama'],
#  ['action', 'comedy'],
#  [],
#  ['horror'],
#  ['horror'],
#  ['drama'],
#  ['comedy'],
#  ['biography', 'drama'],
#  ['drama', 'war'],
#  ['action', 'adventure', 'scifi', 'thriller'],
#  ['adventure', 'drama'],
#  ['drama', 'romance'],
#  ['comedy', 'drama', 'music'],
#  ['war'],
#  ['comedy', 'crime', 'drama'],
#  ['action', 'adventure', 'crime', 'thriller'],
#  [],
#  ['drama', 'musical'],
#  ['action', 'comedy', 'drama', 'family'],
#  ['drama'],
#  ['crime', 'drama', 'thriller'],
#  ['animation', 'family', 'fantasy', 'musical', 'scifi'],
#  ['drama'],
#  ['drama', 'war'],
#  ['animation'],
#  ['action'],
#  ['comedy', 'sport'],
#  ['mystery', 'romance', 'scifi', 'thriller'],
#  ['drama'],
#  ['comedy', 'drama'],
#  ['action', 'adventure', 'comedy', 'crime', 'thriller'],
#  ['comedy', 'drama'],
#  ['animation', 'comedy', 'drama'],
#  ['drama'],
#  [],
#  ['action', 'animation'],
#  ['comedy'],
#  [],
#  ['animation', 'comedy'],
#  ['drama'],
#  ['comedy', 'drama'],
#  ['action', 'crime', 'drama'],
#  ['comedy', 'drama', 'romance'],
#  ['drama'],
#  ['adventure', 'fantasy'],
#  ['comedy'],
#  ['action', 'fantasy', 'thriller'],
#  ['drama', 'romance'],
#  ['comedy', 'horror'],
#  ['drama', 'sport'],
#  ['comedy', 'romance'],
#  ['action', 'adventure', 'fantasy', 'thriller'],
#  ['drama', 'family', 'romance'],
#  ['animation'],
#  ['action', 'adventure', 'drama', 'war'],
#  ['action', 'crime', 'horror', 'thriller'],
#  ['action', 'adventure', 'western'],
#  ['comedy', 'drama', 'family'],
#  ...]

# %%
plot_data['year'] = [str(_).split('-')[0] for _ in plot_data['release date']]

plot_data
# Out:
#                                                    synopsis freebase_id  \
# wiki_id
# 23890098  Shlykov, a hard-working taxi driver and Lyosha...  /m/076w2lb
# 31186339  The nation of Panem consists of a wealthy Capi...  /m/0gkz15s
# 20663735  Poovalli Induchoodan  is sentenced for six yea...  /m/051zjwb
# 2231378   The Lemon Drop Kid , a New York City swindler,...   /m/06xtz3
# 595909    Seventh-day Adventist Church pastor Michael Ch...   /m/02tqm5
# ...                                                     ...         ...
# 34808485  The story is about Reema , a young Muslim scho...  /m/0j3dcl6
# 1096473   In 1928 Hollywood, director Leo Andreyev  look...   /m/045pct
# 35102018  American Luthier focuses on Randy Parsons’ tra...  /m/0j6777g
# 8628195   Abdur Rehman Khan , a middle-aged dry fruit se...  /m/04f7jfs
# 6040782   1940 - Operation Dynamo has just taken place. ...   /m/0fm00m
#
#                                      name release date      revenue  runtime  \
# wiki_id
# 23890098                       Taxi Blues   1990-09-07          NaN    110.0
# 31186339                 The Hunger Games   2012-03-12  686533290.0    142.0
# 20663735                       Narasimham         2000          NaN    175.0
# 2231378                The Lemon Drop Kid   1951-03-08    2300000.0     91.0
# 595909                  A Cry in the Dark   1988-11-03    6908797.0    121.0
# ...                                   ...          ...          ...      ...
# 34808485              Oomakkuyil Padumbol   2012-02-17          NaN      NaN
# 1096473                  The Last Command         1928          NaN     88.0
# 35102018  Randy Parsons: American Luthier   2011-10-04          NaN      8.0
# 8628195                        Kabuliwala   1961-12-14          NaN    134.0
# 6040782                        Dad's Army   1971-03-12          NaN     95.0
#
#                                                   languages  \
# wiki_id
# 23890098                   {"/m/06b_j": "Russian Language"}
# 31186339                 {"/m/02h40lc": "English Language"}
# 20663735                 {"/m/0999q": "Malayalam Language"}
# 2231378                  {"/m/02h40lc": "English Language"}
# 595909                   {"/m/02h40lc": "English Language"}
# ...                                                     ...
# 34808485                 {"/m/0999q": "Malayalam Language"}
# 1096473   {"/m/06ppq": "Silent film", "/m/02h40lc": "Eng...
# 35102018                 {"/m/02h40lc": "English Language"}
# 8628195                      {"/m/03k50": "Hindi Language"}
# 6040782                  {"/m/02h40lc": "English Language"}
#
#                                                   countries  \
# wiki_id
# 23890098  {"/m/0f8l9c": "France", "/m/05vz3zq": "Soviet ...
# 31186339          {"/m/09c7w0": "United States of America"}
# 20663735                              {"/m/03rk0": "India"}
# 2231378           {"/m/09c7w0": "United States of America"}
# 595909    {"/m/09c7w0": "United States of America", "/m/...
# ...                                                     ...
# 34808485                              {"/m/03rk0": "India"}
# 1096473           {"/m/09c7w0": "United States of America"}
# 35102018          {"/m/09c7w0": "United States of America"}
# 8628195                               {"/m/03rk0": "India"}
# 6040782                      {"/m/07ssc": "United Kingdom"}
#
#                                                      genres  year
# wiki_id
# 23890098                              [Drama, World cinema]  1990
# 31186339  [Action/Adventure, Science Fiction, Action, Dr...  2012
# 20663735                [Musical, Action, Drama, Bollywood]  2000
# 2231378                          [Screwball comedy, Comedy]  1951
# 595909    [Crime Fiction, Drama, Docudrama, World cinema...  1988
# ...                                                     ...   ...
# 34808485                                       [Children's]  2012
# 1096473   [Silent film, Indie, Black-and-white, Period p...  1928
# 35102018  [Short Film, Music, Biographical film, Documen...  2011
# 8628195                                             [Drama]  1961
# 6040782                                            [Comedy]  1971
#
# [41785 rows x 10 columns]

# %%
lens = np.array([len(_) for _ in genres_data2])

plot_data['genres'] = genres_data2

idx = np.where(lens!=0)[0].tolist()

plot_data = plot_data.iloc[idx]

# %%
plot_data['genres'] = [[genres[_] for _ in _] for _ in plot_data['genres']]

plot_data = plot_data[['name', 'year', 'revenue', 'genres', 'synopsis']]

plot_data
# Out:
# /tmp/ipykernel_306726/2622315977.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   plot_data['genres'] = [[genres[_] for _ in _] for _ in plot_data['genres']]
#                                      name  year      revenue  \
# wiki_id
# 23890098                       Taxi Blues  1990          NaN
# 31186339                 The Hunger Games  2012  686533290.0
# 20663735                       Narasimham  2000          NaN
# 2231378                The Lemon Drop Kid  1951    2300000.0
# 595909                  A Cry in the Dark  1988    6908797.0
# ...                                   ...   ...          ...
# 2867597   Mr. Bill's Real Life Adventures  1986          NaN
# 1096473                  The Last Command  1928          NaN
# 35102018  Randy Parsons: American Luthier  2011          NaN
# 8628195                        Kabuliwala  1961          NaN
# 6040782                        Dad's Army  1971          NaN
#
#                                       genres  \
# wiki_id
# 23890098                             [Drama]
# 31186339  [Action, Adventure, Drama, Sci-Fi]
# 20663735            [Action, Drama, Musical]
# 2231378                             [Comedy]
# 595909                        [Crime, Drama]
# ...                                      ...
# 2867597                             [Comedy]
# 1096473                         [Drama, War]
# 35102018                  [Biography, Music]
# 8628195                              [Drama]
# 6040782                             [Comedy]
#
#                                                    synopsis
# wiki_id
# 23890098  Shlykov, a hard-working taxi driver and Lyosha...
# 31186339  The nation of Panem consists of a wealthy Capi...
# 20663735  Poovalli Induchoodan  is sentenced for six yea...
# 2231378   The Lemon Drop Kid , a New York City swindler,...
# 595909    Seventh-day Adventist Church pastor Michael Ch...
# ...                                                     ...
# 2867597   An attempt to bring the famed "Mr. Bill" clay ...
# 1096473   In 1928 Hollywood, director Leo Andreyev  look...
# 35102018  American Luthier focuses on Randy Parsons’ tra...
# 8628195   Abdur Rehman Khan , a middle-aged dry fruit se...
# 6040782   1940 - Operation Dynamo has just taken place. ...
#
# [39086 rows x 5 columns]

# %% [markdown]
# ### Cleaning synopses.

# %%
cleaners = {
    'text_num': lambda _ : re.sub(r'\S*[^a-zA-Z\s\.\,0-9-]+\S*', '', _),
    'caps_words': lambda _ : re.sub(r'\S*[A-Z]+\S*', '', _),
    'punct': lambda _ : re.sub(r'[^\w\s]+', '', _),
    'numbers': lambda _ : re.sub(r'[0-9]+', '', _),
    'spaces': lambda _ : re.sub(r'\s+', ' ', _),
    'space_comma': lambda _ : re.sub(r'\s,', ',', _),
    'space_period': lambda _ : re.sub(r'\s\.', '.', _)
}

# %%
def clean(text):
    
    for k in ['text_num', 'spaces', 'space_comma', 'space_period']:
        
        text = cleaners[k](text)
        
    return text

# %%
plot_data['clean'] = plot_data['synopsis'].parallel_apply(clean)
plot_data.head()
# Out:
#                         name  year      revenue  \
# wiki_id
# 23890098          Taxi Blues  1990          NaN
# 31186339    The Hunger Games  2012  686533290.0
# 20663735          Narasimham  2000          NaN
# 2231378   The Lemon Drop Kid  1951    2300000.0
# 595909     A Cry in the Dark  1988    6908797.0
#
#                                       genres  \
# wiki_id
# 23890098                             [Drama]
# 31186339  [Action, Adventure, Drama, Sci-Fi]
# 20663735            [Action, Drama, Musical]
# 2231378                             [Comedy]
# 595909                        [Crime, Drama]
#
#                                                    synopsis  \
# wiki_id
# 23890098  Shlykov, a hard-working taxi driver and Lyosha...
# 31186339  The nation of Panem consists of a wealthy Capi...
# 20663735  Poovalli Induchoodan  is sentenced for six yea...
# 2231378   The Lemon Drop Kid , a New York City swindler,...
# 595909    Seventh-day Adventist Church pastor Michael Ch...
#
#                                                       clean
# wiki_id
# 23890098  Shlykov, a hard-working taxi driver and Lyosha...
# 31186339  The nation of Panem consists of a wealthy Capi...
# 20663735  Poovalli Induchoodan is sentenced for six year...
# 2231378   The Lemon Drop Kid, a New York City swindler, ...
# 595909    Seventh-day Adventist Church pastor Michael Ch...

# %% [markdown]
# ### Saving plot_data and cleaned IMDB_movie_details.json from spoilers dataset

# %%
pkl.dump(plot_data, open(f'{tmp_dir}/data.pkl', 'wb'))

# %%
def read_json_file(file):
    '''
    from https://stackoverflow.com/a/68942058/5242222
    '''
    with open(file, "r") as r:
        response = r.read()
        response = response.replace('\n', '')
        response = response.replace('}{', '},{')
        response = "[" + response + "]"
        return json.loads(response)

# %%
fn = f'{data_dir}/IMDB_movie_details.json'
df_imdb = pd.DataFrame.from_records(read_json_file(fn))
df_imdb = df_imdb[df_imdb['plot_synopsis']!=''].reset_index(drop=True)

df_imdb['clean'] = df_imdb['plot_synopsis'].parallel_apply(clean)
# df_imdb.insert(2, 'clean', df_imdb.pop('clean'))

df_imdb
# Out:
#        movie_id                                       plot_summary  duration  \
# 0     tt0105112  Former CIA analyst, Jack Ryan is in England wi...  1h 57min
# 1     tt1204975  Billy (Michael Douglas), Paddy (Robert De Niro...  1h 45min
# 2     tt0040897  Fred C. Dobbs and Bob Curtin, both down on the...   2h 6min
# 3     tt0126886  Tracy Flick is running unopposed for this year...  1h 43min
# 4     tt0286716  Bruce Banner, a brilliant scientist with a clo...  2h 18min
# ...         ...                                                ...       ...
# 1334  tt0120655  An abortion clinic worker with a special herit...  2h 10min
# 1335  tt0276751  Twelve year old Marcus Brewer lives with his c...  1h 41min
# 1336  tt0289879  Evan Treborn grows up in a small town with his...  1h 53min
# 1337  tt1723811  Brandon is a 30-something man living in New Yo...  1h 41min
# 1338  tt5013056  Evacuation of Allied soldiers from the British...  1h 46min
#
#                             genre rating release_date  \
# 0              [Action, Thriller]    6.9   1992-06-05
# 1                        [Comedy]    6.6   2013-11-01
# 2     [Adventure, Drama, Western]    8.3   1948-01-24
# 3        [Comedy, Drama, Romance]    7.3   1999-05-07
# 4                [Action, Sci-Fi]    5.7   2003-06-20
# ...                           ...    ...          ...
# 1334   [Adventure, Comedy, Drama]    7.3   1999-11-12
# 1335     [Comedy, Drama, Romance]    7.1   2002-05-17
# 1336           [Sci-Fi, Thriller]    7.7   2004-01-23
# 1337                      [Drama]    7.2   2012-01-13
# 1338     [Action, Drama, History]    8.1   2017-07-21
#
#                                           plot_synopsis  \
# 0     Jack Ryan (Ford) is on a "working vacation" in...
# 1     Four boys around the age of 10 are friends in ...
# 2     Fred Dobbs (Humphrey Bogart) and Bob Curtin (T...
# 3     Jim McAllister (Matthew Broderick) is a much-a...
# 4     Bruce Banner (Eric Bana) is a research scienti...
# ...                                                 ...
# 1334  The film opens with a homeless man (Bud Cort) ...
# 1335  Will Freeman (Hugh Grant) is a 38-year-old bac...
# 1336  In the year 1998, Evan Treborn (Ashton Kutcher...
# 1337  Brandon (Michael Fassbender) is a successful, ...
# 1338  The film alternates between three different pe...
#
#                                                   clean
# 0     Jack Ryan is on a in London with his family. H...
# 1     Four boys around the age of 10 are friends in ...
# 2     Fred Dobbs and Bob Curtin are down on their lu...
# 3     Jim McAllister is a much-admired high school h...
# 4     Bruce Banner is a research scientist at a Berk...
# ...                                                 ...
# 1334  The film opens with a homeless man on a desert...
# 1335  Will Freeman is a 38-year-old bachelor who pri...
# 1336  In the year 1998, Evan Treborn who suffered se...
# 1337  Brandon is a successful, handsome thirty-somet...
# 1338  The film alternates between three different pe...
#
# [1339 rows x 8 columns]

# %%
pkl.dump(df_imdb, open(f'{tmp_dir}/df_imdb.pkl', 'wb'))
